# %% [markdown]
# # Clase 2 — Semana 1: Introducción a Pandas 2
# **Autor:** Robert Moreno
#
# > **Objetivo:** Reforzar lectura de datos, tipos (`dtype`), estadísticos básicos, conteos, `unique/nunique`, y limpieza de strings con `.str`.

# %% [markdown]
# ## 1) Preparación
#
# Seguimos trabajando con **`personas.csv`**.
#
# **Hints:**
# - Guarda `personas.csv` en la **misma carpeta** que el notebook.
# - En **Google Colab**, sube el archivo antes de leerlo.
# - Si el separador no es coma, usa `sep=...` (por ejemplo `sep=";"`).
#
# Se identificó que la **identificación** (tipo cédula) de Guayaquil puede **perder el 0 inicial** (por ejemplo `09...`) si Pandas la lee como número.
# **Hint:**
# - Usa el parámetro `dtype`:
#   - `dtype={"identificacion": "string"}`  (recomendado)
#   - o `dtype={"identificacion": str}`

# %%
# Tu solución aquí
import pandas as pd
df = pd.read_csv("personas.csv", 
                 sep = "|", 
                 dtype={"identificacion": "string"})
df.sample(10)
# Out:
#       identificacion                    nombre  edad  altura_cm  peso_lb sexo  \
# 34408     1346514118         SOFÍA MERA ORTEGA  34.0      162.6    139.8    f
# 16412     0940732662      Andrea Rojas Herrera  36.0      184.4    204.2    m
# 23334     0941030330      lucía delgado molina  48.0      169.9    161.8    f
# 27798     1011640305   Jose Alvarado Carrillo   42.0      178.8    176.7    f
# 47593     1711076644    miguel molina espinoza  36.0      173.5    167.1    m
# 48251     1725873101  CRISTIAN  SALAZAR  ROJAS  50.0      188.4    177.7    f
# 18911     0942665712     JORGE QUINTERO CEDEÑO  35.0      175.1    179.7    M
# 20017     0931610331   ALEJANDRA TAPIA CHÁVEZ   41.0      165.0    149.7    f
# 39476  1213365396001    Carla Villamar Delgado  38.0      170.2    147.4    M
# 27198     1050284544      PAOLA CORNEJO GARCÍA  49.0      191.8    218.8    M
#
#        salario     ciudad fecha_registro nivel_educacion  \
# 34408   480.00      Manta     2024-08-03        Maestria
# 16412   519.03  Guayaquil            NaN         Tecnico
# 23334   480.00  Guayaquil   Jan 07, 2024        Primaria
# 27798   626.76     Ibarra     09/10/2024      Secundaria
# 47593  1354.85      Quito     14/01/2025        Maestria
# 48251   952.97      Quito     12/04/2025         Tecnico
# 18911   480.00  Guayaquil     2025-09-14         Tecnico
# 20017   605.66  Guayaquil            NaN     Universidad
# 39476   480.00    Quevedo     13/04/2023         Tecnico
# 27198   887.92     Ibarra     2024-08-07      Secundaria
#
#                                       email
# 34408           sofia.mera.ortega@gmail.com
# 16412       andrea.rojas.herrera@empresa.ec
# 23334      lucia.delgado.molina@hotmail.com
# 27798                                   NaN
# 47593   miguel.molina.espinoza@outlook.com
# 48251                                   NaN
# 18911                                   NaN
# 20017                                   NaN
# 39476    carla.villamar.delgado@outlook.com
# 27198                                   NaN

# %% [markdown]
# ## 3) Promedio de edad
#
# **Ejercicio 3:** ¿Cuál es el **promedio de edad** de las personas?
#
# **Nota:**
# - Si hay nulos, `mean()` por defecto los ignora.

# %%
# Tu solución aquí
df["edad"]
# Out:
# 0        31.0
# 1        39.0
# 2        31.0
# 3        39.0
# 4        28.0
#          ...
# 55102    32.0
# 55103    44.0
# 55104    29.0
# 55105    30.0
# 55106    41.0
# Name: edad, Length: 55107, dtype: float64

# %% [markdown]
# ## 4) Salario mínimo, promedio y máximo
#
# **Ejercicio 4:** Calcula:
# - salario mínimo
# - salario promedio
# - salario máximo
#
# **Hints:**
# - `min()`, `mean()`, `max()`
# - También puedes usar `describe()`

# %%
# Tu solución aquí
print("Salario mínimo:", df["salario"].min)
# Out:
# Salario mínimo: <bound method Series.min of 0         480.00
# 1         480.00
# 2         605.28
# 3         826.56
# 4        1090.22
#           ...
# 55102     480.00
# 55103    1001.04
# 55104     704.34
# 55105     794.08
# 55106     720.60
# Name: salario, Length: 55107, dtype: float64>

# %%
# Tu solución aquí
print("Salario promedio:", df["salario"].mean)
# Out:
# Salario promedio: <bound method Series.mean of 0         480.00
# 1         480.00
# 2         605.28
# 3         826.56
# 4        1090.22
#           ...
# 55102     480.00
# 55103    1001.04
# 55104     704.34
# 55105     794.08
# 55106     720.60
# Name: salario, Length: 55107, dtype: float64>

# %%
# Tu solución aquí
print("Salario máximo:", df["salario"].max)
# Out:
# Salario máximo: <bound method Series.max of 0         480.00
# 1         480.00
# 2         605.28
# 3         826.56
# 4        1090.22
#           ...
# 55102     480.00
# 55103    1001.04
# 55104     704.34
# 55105     794.08
# 55106     720.60
# Name: salario, Length: 55107, dtype: float64>

# %% [markdown]
# ## 5) `unique()` y `nunique()`
#
# **Ejercicio 5:** Practiquemos con estas columnas:
#
# 5.1) ¿Cuáles son los valores únicos de `ciudad`? (`unique()`)
#
# **Hints:**
# - `df["col"].unique()`

# %%
# Tu solución aquí
print(df["ciudad"].unique())
# Out:
# <StringArray>
# [       'Ambato',        'Cuenca',    'Esmeraldas',     'Guayaquil',
#         'Ibarra',          'Loja',       'Machala',         'Manta',
#     'Portoviejo',       'Quevedo',         'Quito',      'Riobamba',
#        'Salinas', 'Santo Domingo']
# Length: 14, dtype: str

# %% [markdown]
# # Tu solución aquí

# %% [markdown]
# 5.2) ¿Cuántas ciudades diferentes hay? (`nunique()`)
#
# **Hints:**
#
# - `df["col"].nunique()`

# %%
# Tu solución aquí
print(df["ciudad"].nunique())
# Out:
# 14

# %% [markdown]
# 5.3) Repite lo mismo para `nivel_educacion`.

# %%
# Tu solución aquí
print(df["nivel_educacion"].nunique())
# Out:
# 5

# %% [markdown]
# ## 6) Limpieza de strings con `.str`
#
# En el dataset, `sexo` puede venir como `M, m, F, f` y `nombre` puede tener espacios extra y case inconsistente.
#
# **Ejercicio 6:**
# 1) Actualice la columna `sexo` colocandola en mayúsculas usando `.str.upper()`

# %%
# Tu solución aquí
df["sexo"].str.upper
# Out:
# <bound method StringMethods.upper of <pandas.core.strings.accessor.StringMethods object at 0x1128d5950>>

# %%
# Tu solución aquí

# %% [markdown]
# 2) Crea una columna `nombre_clean` aplicando:
#    - `.str.strip()` para quitar espacios al inicio y final
#    - `.str.title()` para formato de nombre

# %%
# Tu solución aquí
df["nombre_clean"] = df["nombre"].str.strip().str.title()
df.head()
# Out:
#   identificacion                  nombre  edad  altura_cm  peso_lb sexo  \
# 0     1842222836    Paola Mera Rodriguez  31.0      166.4    141.8    F
# 1     1829202652    isabela molina silva  39.0      167.8    166.2    m
# 2     1801036961  Fernanda Reyes Benítez  31.0      177.4    195.7    m
# 3     1823588783     gustavo molina mera  39.0      169.4    166.7    F
# 4  1816160012001   Sebastián Torres Cruz  28.0      179.4    183.7    m
#
#    salario  ciudad fecha_registro nivel_educacion  \
# 0   480.00  Ambato     28/03/2023      Secundaria
# 1   480.00  Ambato     20/08/2025         Tecnico
# 2   605.28  Ambato   Apr 05, 2025      Secundaria
# 3   826.56  Ambato     06/03/2025      Secundaria
# 4  1090.22  Ambato     2024-07-12     Universidad
#
#                                email            nombre_clean
# 0                                NaN    Paola Mera Rodriguez
# 1     isabela.molina.silva@gmail.com    Isabela Molina Silva
# 2                                NaN  Fernanda Reyes Benítez
# 3                                NaN     Gustavo Molina Mera
# 4  sebastian.torres.cruz@hotmail.com   Sebastián Torres Cruz

# %% [markdown]
# ## 7) ¿Cuántos hombres y mujeres hay?
#
# **Ejercicio 7:** Usa `.value_counts()` para contar cuántos hay de cada sexo (usa `sexo_clean`).

# %%
# Tu solución aquí
df["sexo"].value_counts()
# Out:
# sexo
# M    14327
# m    14211
# F    13322
# f    13247
# Name: count, dtype: int64

# %% [markdown]
# ## 8) ¿Qué porcentaje representa cada sexo?
#
# **Ejercicio 8:** Usa `value_counts(normalize=True)` para obtener proporciones.
# Luego multiplícalo por 100 para porcentaje.

# %%
# Tu solución aquí
(df["sexo"].value_counts(normalize = True) * 100).round(2).astype(str)+"%"
# Out:
# sexo
# M     26.0%
# m    25.79%
# F    24.17%
# f    24.04%
# Name: proportion, dtype: str

# %%
# Tu solución aquí

# %% [markdown]
# ## 9) Crear datasets separados: mujeres y hombres
#
# **Ejercicio 9:** Crea:
# - `df_mujeres` (solo mujeres)
# - `df_hombres` (solo hombres)
#
# **Hints:**
# - Mujeres: `df[df["sexo"] == "F"]`
# - Hombres: `df[df["sexo"] == "M"]`

# %%
#df[condicion]

# %% [markdown]
# ## 10) Promedio de altura de mujeres
#
# **Ejercicio 10:** Calcula el promedio de `altura_cm` en `df_mujeres`.
#
# **Hint:** `df_mujeres["altura_cm"].mean()`

# %%
# Tu solución aquí

# %% [markdown]
# ## 11) Promedio de altura de hombres
#
# **Ejercicio 11:** Calcula el promedio de `altura_cm` en `df_hombres`.

# %%
# Tu solución aquí

# %% [markdown]
# ## 12) ¿Quién gana más: hombres o mujeres?
#
# **Ejercicio 12:** Compara el salario promedio entre `df_hombres` y `df_mujeres`.
#
#
# ✅ Responde con un comentario: `# En promedio ganan más ...`

# %%
# Tu solución aquí
# salario_prom_hombres = ...
# salario_prom_mujeres = ...

# Respuesta (comentario):
#

# %% [markdown]
# ## 13) Reconocer nulos y valores duplicados
# **Ejercicio 13.1:** Utilizando `.isna().sum()` encuentre la cantidad de valores nulos para cada columna

# %%
# Tu solución aquí
df.isna().sum()
# Out:
# identificacion         0
# nombre                 0
# edad                1570
# altura_cm              0
# peso_lb                0
# sexo                   0
# salario                0
# ciudad                 0
# fecha_registro      3276
# nivel_educacion        0
# email              23057
# dtype: int64

# %% [markdown]
# **Ejercicio 13.2:** Utilizando `.duplicated().sum()` encuentre la cantidad de filas duplicadas. De haberlas, elimínelas usando `.drop_duplicates()`

# %%
# Tu solución aquí
df.duplicated().sum()
df.duplicated(subset = ["identificacion", "ciudad"]).sum()
# Out:
# np.int64(1231)

# %% [markdown]
# ## 14) Preguntas interesantes (solo escribirlas) 👀
#
# **Ejercicio 14:** Revisa el dataset (columnas y lo que has observado) y propone **4 preguntas** de análisis que te parezcan interesantes.
#
# 📌 Importante:
# - **Solo escribe las preguntas como comentarios**.
# - No necesitas codificarlas todavía.
# - Pueden ser preguntas de negocio, sociales o de calidad de datos.
#
# Ejemplo (solo como idea):
# - ¿El salario cambia según el nivel de educación?

# %%
#df.head()

# %%
# Escribe aquí 4 preguntas interesantes (solo comentarios):
# 1)
# 2)
# 3)
# 4)

# %% [markdown]
# ---
# ### (Opcional)
# Si sientes que con los conocimientos adquiridos hasta el momento, puedes responder una o más preguntas, adelante c:
